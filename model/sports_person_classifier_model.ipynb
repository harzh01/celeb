# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_image/vk.jpg')
img.shape
# Out:
# (1229, 1080, 3)

# %%
plt.imshow(img)

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (1229, 1080)

# %%
plt.imshow(gray, cmap="gray")

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[212, 231, 654, 654]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (212, 231, 654, 654)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_image/vk.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_image/vk.jpg')
plt.imshow(cropped_image)

# %%
org_image_obstructed = cv2.imread('./test_image/mo_salah.jpg')
plt.imshow(org_image_obstructed)

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/kdb',
#  './dataset/max',
#  './dataset/mo',
#  './dataset/sm',
#  './dataset/vk']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/kdb
# Generating cropped images in folder:  ./dataset/cropped/max
# Generating cropped images in folder:  ./dataset/cropped/mo
# Generating cropped images in folder:  ./dataset/cropped/sm
# Generating cropped images in folder:  ./dataset/cropped/vk

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_image,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
celebrity_file_names_dict
# Out:
# {'kdb': ['./dataset/cropped/kdb/kdb1.png',
#   './dataset/cropped/kdb/kdb2.png',
#   './dataset/cropped/kdb/kdb3.png',
#   './dataset/cropped/kdb/kdb4.png',
#   './dataset/cropped/kdb/kdb5.png',
#   './dataset/cropped/kdb/kdb6.png',
#   './dataset/cropped/kdb/kdb7.png',
#   './dataset/cropped/kdb/kdb8.png',
#   './dataset/cropped/kdb/kdb9.png',
#   './dataset/cropped/kdb/kdb10.png',
#   './dataset/cropped/kdb/kdb11.png',
#   './dataset/cropped/kdb/kdb12.png',
#   './dataset/cropped/kdb/kdb13.png',
#   './dataset/cropped/kdb/kdb14.png',
#   './dataset/cropped/kdb/kdb15.png',
#   './dataset/cropped/kdb/kdb16.png',
#   './dataset/cropped/kdb/kdb17.png',
#   './dataset/cropped/kdb/kdb18.png',
#   './dataset/cropped/kdb/kdb19.png',
#   './dataset/cropped/kdb/kdb20.png',
#   './dataset/cropped/kdb/kdb21.png',
#   './dataset/cropped/kdb/kdb22.png',
#   './dataset/cropped/kdb/kdb23.png',
#   './dataset/cropped/kdb/kdb24.png',
#   './dataset/cropped/kdb/kdb25.png',
#   './dataset/cropped/kdb/kdb26.png',
#   './dataset/cropped/kdb/kdb27.png',
#   './dataset/cropped/kdb/kdb28.png',
#   './dataset/cropped/kdb/kdb29.png',
#   './dataset/cropped/kdb/kdb30.png'],
#  'max': ['./dataset/cropped/max/max1.png',
#   './dataset/cropped/max/max2.png',
#   './dataset/cropped/max/max3.png',
#   './dataset/cropped/max/max4.png',
#   './dataset/cropped/max/max5.png',
#   './dataset/cropped/max/max6.png',
#   './dataset/cropped/max/max7.png',
#   './dataset/cropped/max/max8.png',
#   './dataset/cropped/max/max9.png',
#   './dataset/cropped/max/max10.png',
#   './dataset/cropped/max/max11.png',
#   './dataset/cropped/max/max12.png',
#   './dataset/cropped/max/max13.png',
#   './dataset/cropped/max/max14.png',
#   './dataset/cropped/max/max15.png',
#   './dataset/cropped/max/max16.png',
#   './dataset/cropped/max/max17.png',
#   './dataset/cropped/max/max18.png',
#   './dataset/cropped/max/max19.png',
#   './dataset/cropped/max/max20.png',
#   './dataset/cropped/max/max21.png',
#   './dataset/cropped/max/max22.png',
#   './dataset/cropped/max/max23.png',
#   './dataset/cropped/max/max24.png',
#   './dataset/cropped/max/max25.png',
#   './dataset/cropped/max/max26.png'],
#  'mo': ['./dataset/cropped/mo/mo1.png',
#   './dataset/cropped/mo/mo2.png',
#   './dataset/cropped/mo/mo3.png',
#   './dataset/cropped/mo/mo4.png',
#   './dataset/cropped/mo/mo5.png',
#   './dataset/cropped/mo/mo6.png',
#   './dataset/cropped/mo/mo7.png',
#   './dataset/cropped/mo/mo8.png',
#   './dataset/cropped/mo/mo9.png',
#   './dataset/cropped/mo/mo10.png',
#   './dataset/cropped/mo/mo11.png',
#   './dataset/cropped/mo/mo12.png',
#   './dataset/cropped/mo/mo13.png',
#   './dataset/cropped/mo/mo14.png',
#   './dataset/cropped/mo/mo15.png',
#   './dataset/cropped/mo/mo16.png',
#   './dataset/cropped/mo/mo17.png',
#   './dataset/cropped/mo/mo18.png',
#   './dataset/cropped/mo/mo19.png',
#   './dataset/cropped/mo/mo20.png',
#   './dataset/cropped/mo/mo21.png'],
#  'sm': ['./dataset/cropped/sm/sm1.png',
#   './dataset/cropped/sm/sm2.png',
#   './dataset/cropped/sm/sm3.png',
#   './dataset/cropped/sm/sm4.png',
#   './dataset/cropped/sm/sm5.png',
#   './dataset/cropped/sm/sm6.png',
#   './dataset/cropped/sm/sm7.png',
#   './dataset/cropped/sm/sm8.png',
#   './dataset/cropped/sm/sm9.png',
#   './dataset/cropped/sm/sm10.png',
#   './dataset/cropped/sm/sm11.png',
#   './dataset/cropped/sm/sm12.png',
#   './dataset/cropped/sm/sm13.png',
#   './dataset/cropped/sm/sm14.png',
#   './dataset/cropped/sm/sm15.png',
#   './dataset/cropped/sm/sm16.png',
#   './dataset/cropped/sm/sm17.png',
#   './dataset/cropped/sm/sm18.png',
#   './dataset/cropped/sm/sm19.png',
#   './dataset/cropped/sm/sm20.png',
#   './dataset/cropped/sm/sm21.png',
#   './dataset/cropped/sm/sm22.png',
#   './dataset/cropped/sm/sm23.png',
#   './dataset/cropped/sm/sm24.png',
#   './dataset/cropped/sm/sm25.png',
#   './dataset/cropped/sm/sm26.png',
#   './dataset/cropped/sm/sm27.png',
#   './dataset/cropped/sm/sm28.png',
#   './dataset/cropped/sm/sm29.png'],
#  'vk': ['./dataset/cropped/vk/vk1.png',
#   './dataset/cropped/vk/vk2.png',
#   './dataset/cropped/vk/vk3.png',
#   './dataset/cropped/vk/vk4.png',
#   './dataset/cropped/vk/vk5.png',
#   './dataset/cropped/vk/vk6.png',
#   './dataset/cropped/vk/vk7.png',
#   './dataset/cropped/vk/vk8.png',
#   './dataset/cropped/vk/vk9.png',
#   './dataset/cropped/vk/vk10.png',
#   './dataset/cropped/vk/vk11.png',
#   './dataset/cropped/vk/vk12.png',
#   './dataset/cropped/vk/vk13.png',
#   './dataset/cropped/vk/vk14.png',
#   './dataset/cropped/vk/vk15.png',
#   './dataset/cropped/vk/vk16.png',
#   './dataset/cropped/vk/vk17.png',
#   './dataset/cropped/vk/vk18.png',
#   './dataset/cropped/vk/vk19.png',
#   './dataset/cropped/vk/vk20.png',
#   './dataset/cropped/vk/vk21.png',
#   './dataset/cropped/vk/vk22.png',
#   './dataset/cropped/vk/vk23.png',
#   './dataset/cropped/vk/vk24.png',
#   './dataset/cropped/vk/vk25.png',
#   './dataset/cropped/vk/vk26.png',
#   './dataset/cropped/vk/vk27.png',
#   './dataset/cropped/vk/vk28.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'kdb': 0, 'max': 1, 'mo': 2, 'sm': 3, 'vk': 4}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X)
# Out:
# 134

# %%
len(X[0])
# Out:
# 4096

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (134, 4096)

# %%
X[0]
# Out:
# array([24., 20., 15., ...,  0.,  2.,  0.])

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.6764705882352942

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.62      0.77         8
#            1       0.67      0.75      0.71         8
#            2       0.67      0.40      0.50         5
#            3       0.62      0.83      0.71         6
#            4       0.56      0.71      0.63         7
#
#     accuracy                           0.68        34
#    macro avg       0.70      0.66      0.66        34
# weighted avg       0.71      0.68      0.68        34

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm        0.74
# 1        random_forest        0.60
# 2  logistic_regression        0.76
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.7352941176470589

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.5

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.6470588235294118

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[5, 1, 0, 0, 2],
#        [1, 6, 0, 1, 0],
#        [1, 0, 3, 0, 1],
#        [1, 0, 0, 5, 0],
#        [0, 0, 0, 1, 6]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'kdb': 0, 'max': 1, 'mo': 2, 'sm': 3, 'vk': 4}

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\harzh\anaconda3\lib\site-packages (1.2.0)
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
